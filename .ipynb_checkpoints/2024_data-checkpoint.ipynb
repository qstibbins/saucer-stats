# %%
#Import Dependencies

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import CSV file
file_path = 'data/reports_by_month.csv'
sighting_df = pd.read_csv(file_path)
monthly_2024_df=sighting_df.iloc[4:16, 0:3]
monthly_2024_df.head()
# Out:
#    Sighting Year  Sighting Month  Count
# 4         2024.0              12    931
# 5         2024.0              11    421
# 6         2024.0              10    378
# 7         2024.0               9    270
# 8         2024.0               8    291

# %%
monthly_2024_df.plot.bar(x= 'Sighting Month', y='Count')
plt.title("Number of Sightings by Month")
plt.tight_layout()

plt.show()

# %%
csv2= 'data/sightings_2024.csv'
country_df = pd.read_csv(csv2)
country_counts = country_df["Country"].value_counts().sort_values(ascending=False)
print(country_counts)
# Out:
# Country
# USA               3274
# United Kingdom     125
# Canada             109
# Brazil              56
# India               33
#                   ...
# Cayman Islands       1
# Malta                1
# Denmark              1
# Kazakhstan           1
# Algeria              1
# Name: count, Length: 97, dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(country_counts, labels=country_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title("UFO Sightings by Country 2024", fontsize=8)
plt.show()
